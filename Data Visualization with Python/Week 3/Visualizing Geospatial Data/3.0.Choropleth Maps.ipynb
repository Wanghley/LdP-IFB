# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - Necessário para criar os Choropleth Maps, pois contém os dados de cada país separadamente
# - Chamamos de Geojson File

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df_canada = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)
df_canada.drop(['Type','Coverage','AREA','REG','DEV'],axis=1,inplace=True)
df_canada.rename(columns={'OdName':'country','AreaName':'continent','RegName':'region'},inplace=True)
df_canada['total']=df_canada.sum(axis=1)
df_canada.head(1)
# Out:
#        country continent         region             DevName  1980  1981  1982  \
# 0  Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#    1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203  2635
#
#    2013  total
# 0  2004  58639
#
# [1 rows x 39 columns]

# %% [markdown]
# # Creating the Map

# %%
import folium as folium

# %%
world_map = folium.Map(
    zoom_start=3,
    tiles='Mapbox Bright'
)

world_geo = open('world_map_geo.json').read()
##generating choropleth map using total population of each country to canada
world_map = folium.Choropleth(
    geo_data=world_geo,
    data=df_canada,
    colums=['country','total'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    legend_name='Immigration to Canada'
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8680c69ea45e> in <module>
#      12     key_on='feature.properties.name',
#      13     fill_color='OrRd',
# ---> 14     legend_name='Immigration to Canada'
#      15 )
#      16
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1063         if hasattr(data, 'set_index'):
#    1064             # This is a pd.DataFrame
# -> 1065             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1066         elif hasattr(data, 'to_dict'):
#    1067             # This is a pd.Series
#
# TypeError: 'NoneType' object is not subscriptable

# %%
world_map
